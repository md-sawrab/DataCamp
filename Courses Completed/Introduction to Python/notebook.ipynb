# %% [markdown]
# # Introduction to Python
# Run the hidden code cell below to import the data used in this course.

# %%
# Importing course packages; you can add more too!
import numpy as np
import math

# Import columns as numpy arrays
baseball_names = np.genfromtxt(
    fname="baseball.csv",  # This is the filename
    delimiter=",",  # The file is comma-separated
    usecols=0,  # Use the first column
    skip_header=1,  # Skip the first line
    dtype=str,  # This column contains strings
)
baseball_heights = np.genfromtxt(
    fname="baseball.csv", delimiter=",", usecols=3, skip_header=1
)
baseball_weights = np.genfromtxt(
    fname="baseball.csv", delimiter=",", usecols=4, skip_header=1
)
baseball_ages = np.genfromtxt(
    fname="baseball.csv", delimiter=",", usecols=5, skip_header=1
)

soccer_names = np.genfromtxt(
    fname="soccer.csv",
    delimiter=",",
    usecols=1,
    skip_header=1,
    dtype=str,
    encoding="utf", 
)
soccer_ratings = np.genfromtxt(
    fname="soccer.csv",
    delimiter=",",
    usecols=2,
    skip_header=1,
    encoding="utf", 
)
soccer_positions = np.genfromtxt(
    fname="soccer.csv",
    delimiter=",",
    usecols=3,
    skip_header=1,
    encoding="utf", 
    dtype=str,
)
soccer_heights = np.genfromtxt(
    fname="soccer.csv",
    delimiter=",",
    usecols=4,
    skip_header=1,
    encoding="utf", 
)
soccer_shooting = np.genfromtxt(
    fname="soccer.csv",
    delimiter=",",
    usecols=8,
    skip_header=1,
    encoding="utf", 
)

# %% [markdown]
# ## Take Notes
#
# Add notes about the concepts you've learned and code cells with code you want to keep.

# %% [markdown]
# #### Python
#
# - General Purpose: Build Anything
# - Open Source ! Free !
# - Python Packages , also for data science

# %% [markdown]
# ### Python Use
#
# - For quick calculation
# - Develop a database-driven website
# - Clean and analyse data

# %% [markdown]
# ### Pyton Comment
#
# - Comments can be used to explain Python code.
# - Comments can be used to make the code more readable.
# - Comments starts with a #, and Python will ignore them.

# %% [markdown]
# #### Python as a calculator

# %%
# Addition
print(4+5)

# Subtraction
print(5-5)

# Multiplication
print(3*5)

# Division
print(10/2)
# Out:
# 9
# 0
# 15
# 5.0

# %% [markdown]
# #### Python variable
#
# - Specefic, Case sensetive name
# - Call up value through variable name
# - Create variable with = (assingment)
#
# `Height = 1.79 ||
# Weight = 68`

# %%
 Height = 1.79
 Weight = 68
 bmi = Weight / Height ** 2
 print(bmi)
# Out:
# 21.22280827689523

# %% [markdown]
# Data Types
#
# - String
# - Integer
# - Float
# - Boolean

# %%
Type_Check = type(bmi)
print(Type_Check)

Day_of_Week = 5
print(type(Day_of_Week))

Name = "Sawrab"
print(type(Name))
# Out:
# <class 'float'>
# <class 'int'>
# <class 'str'>

# %%
print(2+2)

print("Md" + " " + "Sawrab")

# different types = different behavior
# Out:
# 4
# Md Sawrab

# %%
# Variable assing

# Create a variable savings
savings = 100

# Print out savings
print(savings)
# Out:
# 100

# %%
Savings = 100
Total_savings = 150

print("I started with $" + str(Savings) + " and now have $" + str(Total_savings) + ". Awesome!") # Python Concenate only string to srting
# Out:
# I started with $100 and now have $150. Awesome!

# %% [markdown]
# ## Python List
#
# - Python list is also a data type.
# - Name a collection of value
# - List content all of data types
# - List create with []

# %%
Name = ["Palash", "Talha"]
print(Name)

print(type(Name))
# Out:
# ['Palash', 'Talha']
# <class 'list'>

# %%
palash = 24
talha = 22
sawrab = 21

age  = [palash, talha , sawrab]
print(age)

print(type(age))
# Out:
# [24, 22, 21]
# <class 'list'>

# %%
# list with different types

dif_list = ["palash", 24 , "talha", 22]
print(dif_list)
# Out:
# ['palash', 24, 'talha', 22]

# %%
# list of list

list_list = [["palash", 24],
            ["talha",22]]
print(list_list)
print(type(list_list))
# Out:
# [['palash', 24], ['talha', 22]]
# <class 'list'>

# %% [markdown]
# ## Subsetting List
#
# - listname[index-number]
# - list index number start with 0

# %%
print(age)
# Out:
# [21]

# %%
# now we want subsetting 22 then call with index
# ar earlier we know index start with 0

age[1]
# Out:
# 22

# %%
# if we print out last element, negative index start with -1

age[-1]
# Out:
# 21

# %%
# after subsetting we can calculate this elements

sum_ = age[1] + age [-1]
print(sum_)

# slicing and dicing
 # we can slice list like slice of cake
    
age[:2]

print(age[0:])
# Out:
# 43
# [24, 22, 21]

# %%
x = [["a", "b", "c"],
     ["d", "e", "f"],
     ["g", "h", "i"]]
x[2][0] # x[row index][colum index]
x[2][:2]
# Out:
# ['g', 'h']

# %% [markdown]
# ## Manipulate list
#
# -  replace list elements
# -  extend, delete

# %%
age = [21,23,34,45,34,23,22,33]

# change 22 instead of 23
age[1] = 23
print(age)

#extend list
ex_age = age + [25,26]
print(ex_age)

#copy

copy = age[:]
print(copy)
# Out:
# [21, 23, 34, 45, 34, 23, 22, 33]
# [21, 23, 34, 45, 34, 23, 22, 33, 25, 26]
# [21, 23, 34, 45, 34, 23, 22, 33]

# %% [markdown]
# ## Python Function
#
# - Nothing New !
# - type # its a function
# - peace of reusable code
# - solve particular task

# %%
print(age)

# max no of age
max(age)

x = 5.444
round(x,1)

# len of age list

len(age)
# Out:
# [21, 23, 34, 45, 34, 23, 22, 33]
# 8

# %%
#sort

sorted(age, reverse = True) #true means desending ordr

#string method

name  = "sawrab"
name.upper()
# Out:
# 'SAWRAB'

# %%
# list method

age = [21,23,34,45,34,23,22,33]

print(age.index(23))

# count

print(age.count(45))
# Out:
# 1
# 1

# %%
age = [21,23,34,45,34,23,22,33]
age.append(54)
print(age)

#reverse

age.reverse()
print(age)
# Out:
# [21, 23, 34, 45, 34, 23, 22, 33, 54]
# [54, 33, 22, 23, 34, 45, 34, 23, 21]

# %% [markdown]
# ## Packege
#
# - Directory of python scripr
# - Each script = Module
# - specify functions, module
# - thousend of packge avaiable

# %%
# Import the math package
import math

# Definition of radius
r = 0.43

# Calculate C
C = 2*(math.pi)*3

# Calculate A
A = math.pi*3**2

print(A)
# Out:
# 28.274333882308138

# %%
# selective import

# Import radians function of math package
from math import radians

# Definition of radius
r = 192500

# Travel distance of Moon over 12 degrees. Store in dist.
dist = r*radians(12)

# Print out dist
print(dist)
# Out:
# 40317.10572106901

# %% [markdown]
# ## Numpy
#
# - Numerical Operations
# - speed, easy and fast
# - alternative of python list
# - numpy containt only one type

# %%
import numpy as np

weight = [180, 215, 210, 210, 188, 176, 209, 200]

np_weight = np.array(weight)
print(type(np_weight))
# Out:
# <class 'numpy.ndarray'>
