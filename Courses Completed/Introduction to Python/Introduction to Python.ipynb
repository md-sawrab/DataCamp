# %% [markdown]
# # Introduction to Python
# Run the hidden code cell below to import the data used in this course.

# %%
# Importing course packages; you can add more too!
import numpy as np
import math

# Import columns as numpy arrays
baseball_names = np.genfromtxt(
    fname="baseball.csv",  # This is the filename
    delimiter=",",  # The file is comma-separated
    usecols=0,  # Use the first column
    skip_header=1,  # Skip the first line
    dtype=str,  # This column contains strings
)
baseball_heights = np.genfromtxt(
    fname="baseball.csv", delimiter=",", usecols=3, skip_header=1
)
baseball_weights = np.genfromtxt(
    fname="baseball.csv", delimiter=",", usecols=4, skip_header=1
)
baseball_ages = np.genfromtxt(
    fname="baseball.csv", delimiter=",", usecols=5, skip_header=1
)

soccer_names = np.genfromtxt(
    fname="soccer.csv",
    delimiter=",",
    usecols=1,
    skip_header=1,
    dtype=str,
    encoding="utf", 
)
soccer_ratings = np.genfromtxt(
    fname="soccer.csv",
    delimiter=",",
    usecols=2,
    skip_header=1,
    encoding="utf", 
)
soccer_positions = np.genfromtxt(
    fname="soccer.csv",
    delimiter=",",
    usecols=3,
    skip_header=1,
    encoding="utf", 
    dtype=str,
)
soccer_heights = np.genfromtxt(
    fname="soccer.csv",
    delimiter=",",
    usecols=4,
    skip_header=1,
    encoding="utf", 
)
soccer_shooting = np.genfromtxt(
    fname="soccer.csv",
    delimiter=",",
    usecols=8,
    skip_header=1,
    encoding="utf", 
)

# %% [markdown]
#    ### Python Basics
#
# - General Purpose: Build Anything
# - Open Source ! Free !
# - Python Packages , also for data scienceyour notes here_

# %% [markdown]
# #### Comment
#
# - Use for understanding code
# - Use '#' to comment

# %%
# Print my name

name = 'Sawrab'

print(name)
# Out:
# Sawrab

# %%
# Calculation in python

# Addition
print(4+5)

# Subtraction
print(5-5)

# Multiplication
print(3*5)

# Division
print(10/2)

# Modulas
print(10%4)

# Floor division
print(6//2)
# Out:
# 9
# 0
# 15
# 5.0
# 2
# 3

# %% [markdown]
# #### Variable
#
# In Python, a variable allows you to refer to a value with a name

# %%
age = 23 # Here age is called variable name and 23 is value. Value assin using '='(assingment) operator

print(age)
# Out:
# 23

# %%
# Another Example

year = 2024

print(year)
# Out:
# 2024

# %%
# Calculation using variable

monthly_savings = 30
months = 12

Yearly_saving = monthly_savings * months

print(Yearly_saving)
# Out:
# 360

# %% [markdown]
# #### Data Type

# %% [markdown]
# - String
# - Float
# - Int
# - Boolean

# %%
name = 'Sawrab'

print(type(name))
# Out:
# <class 'str'>

# %%
water = 2.5

print(type(water))
# Out:
# <class 'float'>

# %%
Taste_good = True 

print(type(Taste_good))
# Out:
# <class 'bool'>

# %% [markdown]
# #### Operations With Types

# %% [markdown]
# Different types different behavior

# %%
a = 5
b = 6

sum = a+b
print(sum)
# Out:
# 11

# %%
First_name = 'Md'
last_name = 'Sawrab'

Full_name = First_name + ' ' + last_name 
print(Full_name)
# Out:
# Md Sawrab

# %% [markdown]
# #### Type Conversion

# %%
# Int to Str

age = 21 # Here value in int type

new_type = str(age)
print(type(new_type))
# Out:
# <class 'str'>

# %% [markdown]
# ### Python List

# %% [markdown]
# #### Creating list

# %% [markdown]
# - List containt any types
# - List start and end with '[]'

# %%
name_list = ['ashik', 'imran', 'sawrab','jahidul']

print(name_list)
# Out:
# ['ashik', 'imran', 'sawrab', 'jahidul']

# %%
print(type(name_list))
# Out:
# <class 'list'>

# %%
# list with different types

diff_types_list = ['ashik', 'imran', 21,22,5.7]

print(diff_types_list)
# Out:
# ['ashik', 'imran', 21, 22, 5.7]

# %%
# list of list

name_age = [['ashik', 24], ['imran', 22]]

print(name_age)
# Out:
# [['ashik', 24], ['imran', 22]]

# %% [markdown]
# #### Subsetting and slicing

# %% [markdown]
# Indexing start with 0

# %%
name_list = ['ashik', 'imran', 'sawrab','jahidul']

# access jahidul from name_list

print(name_list[3])
# Out:
# jahidul

# %%
print(name_list[-1]) # is called negative indexing
# Out:
# jahidul

# %%
# Subsetting and Calculation

tk = [30,4,56,7,8]

A30_ = tk[0]
B56_ = tk[2]

total = A30_ + B56_

print(total)
# Out:
# 86

# %%
# Slicing 

name_list = ['ashik', 'imran', 'sawrab','jahidul']

print(name_list[0:3]) # last number excluted form output
# Out:
# ['ashik', 'imran', 'sawrab']

# %%
print(name_list[:4])

print(name_list[1:])
# Out:
# ['ashik', 'imran', 'sawrab', 'jahidul']
# ['imran', 'sawrab', 'jahidul']

# %%
# Subsetting list of list

name_age = [['ashik', 24], ['imran', 22]]

print(name_age[0][1])
# Out:
# 24

# %% [markdown]
# #### Manipulate list

# %%
# Replace
name_list = ['ashik', 'imran', 'sawrab','jahidul']

name_list[3] = 'rakib'

print(name_list)
# Out:
# ['ashik', 'imran', 'sawrab', 'rakib']

# %%
# Extend

list_ext = name_list + ['Jahidul']

print(list_ext)
# Out:
# ['ashik', 'imran', 'sawrab', 'rakib', 'Jahidul']

# %%
# Remove

del list_ext[2]

list_ext
# Out:
# ['ashik', 'imran', 'rakib', 'Jahidul']

# %% [markdown]
# ### Function and Package

# %% [markdown]
# Python offers a bunch of built-in functions to make your life as a data scientist easier. You already know two such functions: print() and type(). You've also used the functions str(), int(), bool() and float() to switch between data types. These are built-in functions as well.

# %% [markdown]
# #### Basic Function

# %%
name = 'sawrab'

type(name) # this is a build in function
# Out:
# str

# %%
len(name) # this is also
# Out:
# 6

# %%
list_ = [1,2,3,4,5,6,7,8,9]

sort = sorted(list_, reverse = True) # reverse = True returned desending order

sort
# Out:
# [9, 8, 7, 6, 5, 4, 3, 2, 1]

# %% [markdown]
# #### String Method

# %%
print(name.upper())
# Out:
# SAWRAB

# %% [markdown]
# #### List Method

# %% [markdown]
# - index(), to get the index of the first element of a list that matches its input and
# - count(), to get the number of times an element appears in a list.

# %%
name_list = ['ashik', 'imran', 'sawrab','jahidul']

print(name_list.index('sawrab'))
# Out:
# 2

# %%
print(name_list.count('sawrab'))
# Out:
# 1

# %%
name_list.append('rabbi')
name_list
# Out:
# ['ashik', 'imran', 'sawrab', 'jahidul', 'rabbi']

# %%
name_list.reverse()

name_list
# Out:
# ['rabbi', 'jahidul', 'sawrab', 'imran', 'ashik']

# %% [markdown]
# #### Import Package

# %%
import math

# Definition of radius
r = 0.43

C = 2*(math.pi)*3

A = math.pi*3**2

print("Circumference: " + str(C))
print("Area: " + str(A))
# Out:
# Circumference: 18.84955592153876
# Area: 28.274333882308138

# %%
# Selective import
from math import radians

# Definition of radius
r = 192500

# Travel distance of Moon over 12 degrees. Store in dist.
dist = r*radians(12)

# Print out dist
print(dist)
# Out:
# 40317.10572106901

# %% [markdown]
# ### Numpy

# %% [markdown]
# #### Create Numpy array

# %%
# Import numpy 

import numpy as np

# %%
baseball = [180, 215, 210, 210, 188, 176, 209, 200]

np_baseball = np.array(baseball)

print(np_baseball)
# Out:
# [180 215 210 210 188 176 209 200]

# %% [markdown]
# #### Subsetting

# %%
np_baseball[2]
# Out:
# 210

# %%
np_baseball[2:5]
# Out:
# array([210, 210, 188])

# %% [markdown]
# #### 2D array

# %%
age = [[2000, 24], [2002, 22]]

np_age = np.array(age)

np.ndim(np_age)
# Out:
# 2

# %%
# Subsetting 2D array

np_age[0,0:2]
# Out:
# array([2000,   24])

# %% [markdown]
# #### Numpy Statistics

# %%
stat = [1,2,3,4,5,6,7,8,9,3,4,5]

np_stat = np.array(stat)

# %%
# mean

np_stat.mean()
# Out:
# 4.75

# %%
# median

np.median(np_stat)
# Out:
# 4.5
