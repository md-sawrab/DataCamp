# %% [markdown]
# # Intermediate Python
# Run the hidden code cell below to import the data used in this course.

# %%
# Import the course packages
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# Import the two datasets
gapminder = pd.read_csv("datasets/gapminder.csv")
brics = pd.read_csv("datasets/brics.csv")

# %% [markdown]
# ## Take Notes
#
# Add notes about the concepts you've learned and code cells with code you want to keep.

# %%
gapminder.head(10)
# Out:
#        country  year   population      cont  life_exp       gdp_cap
# 0  Afghanistan  2007   31889923.0      Asia    43.828    974.580338
# 1      Albania  2007    3600523.0    Europe    76.423   5937.029526
# 2      Algeria  2007   33333216.0    Africa    72.301   6223.367465
# 3       Angola  2007   12420476.0    Africa    42.731   4797.231267
# 4    Argentina  2007   40301927.0  Americas    75.320  12779.379640
# 5    Australia  2007   20434176.0   Oceania    81.235  34435.367440
# 6      Austria  2007    8199783.0    Europe    79.829  36126.492700
# 7      Bahrain  2007     708573.0      Asia    75.635  29796.048340
# 8   Bangladesh  2007  150448339.0      Asia    64.062   1391.253792
# 9      Belgium  2007   10392226.0    Europe    79.441  33692.605080

# %%
brics.head(10)
# Out:
#   country_ab       country    capital    area  population
# 0         BR        Brazil   Brasilia   8.516      200.40
# 1         RU        Russia     Moscow  17.100      143.50
# 2         IN         India  New Delhi   3.286     1252.00
# 3         CH         China    Beijing   9.597     1357.00
# 4         SA  South Africa   Pretoria   1.221       52.98

# %% [markdown]
# # Line Chart

# %%
year = [1950, 1951, 1952, 1953, 1954, 1955, 1956, 1957, 1958, 1959, 1960, 1961, 1962, 1963, 1964, 1965, 1966, 1967, 1968, 1969, 1970, 1971, 1972, 1973, 1974, 1975, 1976, 1977, 1978, 1979, 1980, 1981, 1982, 1983, 1984, 1985, 1986, 1987, 1988, 1989, 1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022, 2023, 2024, 2025, 2026, 2027, 2028, 2029, 2030, 2031, 2032, 2033, 2034, 2035, 2036, 2037, 2038, 2039, 2040, 2041, 2042, 2043, 2044, 2045, 2046, 2047, 2048, 2049, 2050, 2051, 2052, 2053, 2054, 2055, 2056, 2057, 2058, 2059, 2060, 2061, 2062, 2063, 2064, 2065, 2066, 2067, 2068, 2069, 2070, 2071, 2072, 2073, 2074, 2075, 2076, 2077, 2078, 2079, 2080, 2081, 2082, 2083, 2084, 2085, 2086, 2087, 2088, 2089, 2090, 2091, 2092, 2093, 2094, 2095, 2096, 2097, 2098, 2099, 2100]

Population = [2.53, 2.57, 2.62, 2.67, 2.71, 2.76, 2.81, 2.86, 2.92, 2.97, 3.03, 3.08, 3.14, 3.2, 3.26, 3.33, 3.4, 3.47, 3.54, 3.62, 3.69, 3.77, 3.84, 3.92, 4.0, 4.07, 4.15, 4.22, 4.3, 4.37, 4.45, 4.53, 4.61, 4.69, 4.78, 4.86, 4.95, 5.05, 5.14, 5.23, 5.32, 5.41, 5.49, 5.58, 5.66, 5.74, 5.82, 5.9, 5.98, 6.05, 6.13, 6.2, 6.28, 6.36, 6.44, 6.51, 6.59, 6.67, 6.75, 6.83, 6.92, 7.0, 7.08, 7.16, 7.24, 7.32, 7.4, 7.48, 7.56, 7.64, 7.72, 7.79, 7.87, 7.94, 8.01, 8.08, 8.15, 8.22, 8.29, 8.36, 8.42, 8.49, 8.56, 8.62, 8.68, 8.74, 8.8, 8.86, 8.92, 8.98, 9.04, 9.09, 9.15, 9.2, 9.26, 9.31, 9.36, 9.41, 9.46, 9.5, 9.55, 9.6, 9.64, 9.68, 9.73, 9.77, 9.81, 9.85, 9.88, 9.92, 9.96, 9.99, 10.03, 10.06, 10.09, 10.13, 10.16, 10.19, 10.22, 10.25, 10.28, 10.31, 10.33, 10.36, 10.38, 10.41, 10.43, 10.46, 10.48, 10.5, 10.52, 10.55, 10.57, 10.59, 10.61, 10.63, 10.65, 10.66, 10.68, 10.7, 10.72, 10.73, 10.75, 10.77, 10.78, 10.79, 10.81, 10.82, 10.83, 10.84, 10.85]

plt.plot(year,Population)

plt.show()

# %%
plt.plot(gapminder["gdp_cap"],gapminder["life_exp"])

plt.show()

# %% [markdown]
# # Scatter Plot

# %%
plt.scatter(gapminder["gdp_cap"],gapminder["life_exp"])
plt.xscale("log")

plt.show()

# %%
plt.scatter(gapminder["population"],gapminder["life_exp"])

plt.show()

# %% [markdown]
# # Histogram

# %%
plt.hist(gapminder["life_exp"])

plt.show()

# %%
plt.hist(gapminder["life_exp"],bins= 5)


plt.show()
plt.clf()

# %% [markdown]
# ## Customization

# %%
year = [1950, 1951, 1952, 1953, 1954, 1955, 1956, 1957, 1958, 1959, 1960, 1961, 1962, 1963, 1964, 1965, 1966, 1967, 1968, 1969, 1970, 1971, 1972, 1973, 1974, 1975, 1976, 1977, 1978, 1979, 1980, 1981, 1982, 1983, 1984, 1985, 1986, 1987, 1988, 1989, 1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022, 2023, 2024, 2025, 2026, 2027, 2028, 2029, 2030, 2031, 2032, 2033, 2034, 2035, 2036, 2037, 2038, 2039, 2040, 2041, 2042, 2043, 2044, 2045, 2046, 2047, 2048, 2049, 2050, 2051, 2052, 2053, 2054, 2055, 2056, 2057, 2058, 2059, 2060, 2061, 2062, 2063, 2064, 2065, 2066, 2067, 2068, 2069, 2070, 2071, 2072, 2073, 2074, 2075, 2076, 2077, 2078, 2079, 2080, 2081, 2082, 2083, 2084, 2085, 2086, 2087, 2088, 2089, 2090, 2091, 2092, 2093, 2094, 2095, 2096, 2097, 2098, 2099, 2100]

Population = [2.53, 2.57, 2.62, 2.67, 2.71, 2.76, 2.81, 2.86, 2.92, 2.97, 3.03, 3.08, 3.14, 3.2, 3.26, 3.33, 3.4, 3.47, 3.54, 3.62, 3.69, 3.77, 3.84, 3.92, 4.0, 4.07, 4.15, 4.22, 4.3, 4.37, 4.45, 4.53, 4.61, 4.69, 4.78, 4.86, 4.95, 5.05, 5.14, 5.23, 5.32, 5.41, 5.49, 5.58, 5.66, 5.74, 5.82, 5.9, 5.98, 6.05, 6.13, 6.2, 6.28, 6.36, 6.44, 6.51, 6.59, 6.67, 6.75, 6.83, 6.92, 7.0, 7.08, 7.16, 7.24, 7.32, 7.4, 7.48, 7.56, 7.64, 7.72, 7.79, 7.87, 7.94, 8.01, 8.08, 8.15, 8.22, 8.29, 8.36, 8.42, 8.49, 8.56, 8.62, 8.68, 8.74, 8.8, 8.86, 8.92, 8.98, 9.04, 9.09, 9.15, 9.2, 9.26, 9.31, 9.36, 9.41, 9.46, 9.5, 9.55, 9.6, 9.64, 9.68, 9.73, 9.77, 9.81, 9.85, 9.88, 9.92, 9.96, 9.99, 10.03, 10.06, 10.09, 10.13, 10.16, 10.19, 10.22, 10.25, 10.28, 10.31, 10.33, 10.36, 10.38, 10.41, 10.43, 10.46, 10.48, 10.5, 10.52, 10.55, 10.57, 10.59, 10.61, 10.63, 10.65, 10.66, 10.68, 10.7, 10.72, 10.73, 10.75, 10.77, 10.78, 10.79, 10.81, 10.82, 10.83, 10.84, 10.85]


plt.plot(year, Population)

plt.xlabel('year')
plt.ylabel('Population') #Not Working

plt.show()

# %% [markdown]
# ## Chapter 2: Dictionaries & Pandas

# %%
dic = {"agfanistan": 30.55, "albania": 2.77, "algeria": 39.44}

#country name are key and theri corresponding value

print(dic["albania"])
# Out:
# 2.77

# %%
countries = ['spain', 'france', 'germany', 'norway']
capitals = ['madrid', 'paris', 'berlin', 'oslo']

europe = {'spain':'madrid', 'france': 'paris','germany': 'berlin', 'norway': 'oslo' }

print(europe['france'])

print(europe.keys())
# Out:
# paris
# dict_keys(['spain', 'france', 'germany', 'norway'])

# %% [markdown]
# - Keys of dictonay should be unique
# - Immutable object

# %%
europe['sealend'] = 0.000027

print(europe)

'sealend' in europe

europe['sealend'] = 0.000028

print(europe)
# Out:
# {'spain': 'madrid', 'france': 'paris', 'germany': 'berlin', 'norway': 'oslo', 'sealend': 2.7e-05}
# {'spain': 'madrid', 'france': 'paris', 'germany': 'berlin', 'norway': 'oslo', 'sealend': 2.8e-05}

# %%
del europe['sealend']

print(europe)
# Out:
# {'spain': 'madrid', 'france': 'paris', 'germany': 'berlin', 'norway': 'oslo'}

# %% [markdown]
# ## List vs Dict
#
# list:
# - Select update and remove with []
# - indexed by range of number
# - collection of values - orders matters,for selecting entire subset
#
# dict:
# - Select update and remove with []
# - indexed by unique keys
# - lookup table with unique keys

# %%
# Manipulation


europe = {'spain':'madrid', 'france':'paris', 'germany':'berlin', 'norway':'oslo' }

# Add
europe['italy'] = 'rome'

# Print 
print('italy' in europe)

# Add poland 
europe['poland'] = 'warsaw'

print(europe)
# Out:
# True
# {'spain': 'madrid', 'france': 'paris', 'germany': 'berlin', 'norway': 'oslo', 'italy': 'rome', 'poland': 'warsaw'}

# %%
europe = {'spain':'madrid', 'france':'paris', 'germany':'bonn',
          'norway':'oslo', 'italy':'rome', 'poland':'warsaw',
          'australia':'vienna' }

# Update 
europe['germany'] ='berlin'

# Remove australia
del europe['australia']

print(europe)
# Out:
# {'spain': 'madrid', 'france': 'paris', 'germany': 'berlin', 'norway': 'oslo', 'italy': 'rome', 'poland': 'warsaw'}

# %%
europe = { 'spain': { 'capital':'madrid', 'population':46.77 },
           'france': { 'capital':'paris', 'population':66.03 },
           'germany': { 'capital':'berlin', 'population':80.62 },
           'norway': { 'capital':'oslo', 'population':5.084 } }


# Print out the capital of France
print(europe['france']['capital'])

# Create sub-dictionary data
data = {'capital': 'rome', 'population': 59.83}

# Add data to europe under key 'italy'
europe['italy'] = data

# Print europe
print(europe)
# Out:
# paris
# {'spain': {'capital': 'madrid', 'population': 46.77}, 'france': {'capital': 'paris', 'population': 66.03}, 'germany': {'capital': 'berlin', 'population': 80.62}, 'norway': {'capital': 'oslo', 'population': 5.084}, 'italy': {'capital': 'rome', 'population': 59.83}}

# %% [markdown]
# ## Pandas Part 1
#
# - High level data manipulation tools
# - Build on numpy

# %%
# names, containing the country names for which data is available.
# dr, a list with booleans that tells whether people drive left or right in the corresponding country.
# cpc, the number of motor vehicles per 1000 people in the corresponding country.

names = ['United States', 'Australia', 'Japan', 'India', 'Russia', 'Morocco', 'Egypt']
dr =  [True, False, False, False, True, True, True]
cpc = [809, 731, 588, 18, 200, 70, 45]


# Import pandas as pd
import pandas as pd

# Create dictionary my_dict with three key:value pairs: my_dict
my_dict = {'country': names, 'drives_right': dr, 'cars_per_cap': cpc}

# Build a DataFrame cars from my_dict: cars
cars = pd.DataFrame(my_dict)

# Definition of row_labels
row_labels = ['US', 'AUS', 'JPN', 'IN', 'RU', 'MOR', 'EG']

# Specify row labels of cars
cars.index = row_labels


# Print cars
print(cars)
# Out:
#            country  drives_right  cars_per_cap
# US   United States          True           809
# AUS      Australia         False           731
# JPN          Japan         False           588
# IN           India         False            18
# RU          Russia          True           200
# MOR        Morocco          True            70
# EG           Egypt          True            45

# %% [markdown]
# - To import CSV data into Python as a Pandas DataFrame you can use read_csv().
# -  index_col, an argument of read_csv(), that you can use to specify which column in the CSV file should be used as a row label

# %% [markdown]
# ### Index and select data
#
# - square Method
# - Advanced
#         - loc
#         - iloc

# %%
brics = pd.read_csv("datasets/brics.csv")
print(brics)
# Out:
#   country_ab       country    capital    area  population
# 0         BR        Brazil   Brasilia   8.516      200.40
# 1         RU        Russia     Moscow  17.100      143.50
# 2         IN         India  New Delhi   3.286     1252.00
# 3         CH         China    Beijing   9.597     1357.00
# 4         SA  South Africa   Pretoria   1.221       52.98

# %%
# accessing
brics['country']
print(type(brics['country']))
# Out:
# <class 'pandas.core.series.Series'>

# %%
brics[["country"]]
print(type(brics[['country']]))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %% [markdown]
# - loc(label based)
# - iloc(integer based)

# %%
brics.loc[1]
# Out:
# country_ab        RU
# country       Russia
# capital       Moscow
# area            17.1
# population     143.5
# Name: 1, dtype: object

# %%
brics.loc[[1,2,4]]
# Out:
#   country_ab       country    capital    area  population
# 1         RU        Russia     Moscow  17.100      143.50
# 2         IN         India  New Delhi   3.286     1252.00
# 4         SA  South Africa   Pretoria   1.221       52.98

# %% [markdown]
# brics.loc[[row_labels], [column]]

# %%
brics.iloc[[1]]
# Out:
#   country_ab country capital  area  population
# 1         RU  Russia  Moscow  17.1       143.5

# %%
brics.iloc[[1,2,3], [0,1]]
# Out:
#   country_ab country
# 1         RU  Russia
# 2         IN   India
# 3         CH   China

# %%
brics.iloc[:, [0,1]]
# Out:
#   country_ab       country
# 0         BR        Brazil
# 1         RU        Russia
# 2         IN         India
# 3         CH         China
# 4         SA  South Africa

# %% [markdown]
# ### Logic, Control Flow and Filtering

# %% [markdown]
# #### Comparison
#
# - Comparison alaways same type

# %%
# Comparison of booleans
True == False

# Comparison of integers
print(-5 * 15 != 75)

# Comparison of strings
print('pyscript' == 'PyScript')

# Compare a boolean with an integer
print(True == 1)
# Out:
# True
# False
# True

# %%
# Comparison of integers
x = -3 * 6
print(x>= -10)

# Comparison of strings
y = "test"
print('test' <= y)

# Comparison of booleans
print(True>False)
# Out:
# False
# True
# True

# %%
# We also compare numpy arrays

import numpy as np
my_house = np.array([18.0, 20.0, 10.75, 9.50])
your_house = np.array([14.0, 24.0, 14.25, 9.0])

# my_house greater than or equal to 18
print(my_house>=18)

# my_house less than your_house
print(my_house<your_house)
# Out:
# [ True  True False False]
# [False  True  True False]

# %% [markdown]
# Opertator
# - AND
# - OR
# - NOT
#
# Numpy
#
# - logical_and()
# - logical_or()
# - logical_not()
# - np.logical_and  (bmi>12,bmi<23)

# %%
my_kitchen = 18.0
your_kitchen = 14.0

# my_kitchen bigger than 10 and smaller than 18?
print(my_kitchen > 10 and my_kitchen < 18)

# my_kitchen smaller than 14 or bigger than 17?
print(my_kitchen < 14 or my_kitchen > 17)

# Double my_kitchen smaller than triple your_kitchen?
print(my_kitchen*2 < your_kitchen*3)
# Out:
# False
# True
# True

# %% [markdown]
# #### IF , Else, Elif

# %%
room = "bed"
area = 14.0

# if-elif-else construct for room
if room == "kit" :
    print("looking around in the kitchen.")
elif room == "bed":
    print("looking around in the bedroom.")
else :
    print("looking around elsewhere.")

# if-elif-else construct for area
if area > 15 :
    print("big place!")
elif area> 10:
    print('medium size, nice!')
else :
    print("pretty small.")
# Out:
# looking around in the bedroom.
# medium size, nice!

# %% [markdown]
# #### pandas x condition

# %%
brics
# Out:
#   country_ab       country    capital    area  population
# 0         BR        Brazil   Brasilia   8.516      200.40
# 1         RU        Russia     Moscow  17.100      143.50
# 2         IN         India  New Delhi   3.286     1252.00
# 3         CH         China    Beijing   9.597     1357.00
# 4         SA  South Africa   Pretoria   1.221       52.98

# %%
brics['area']

is_huge = brics['area'] > 8
brics[is_huge]
# Out:
#   country_ab country   capital    area  population
# 0         BR  Brazil  Brasilia   8.516       200.4
# 1         RU  Russia    Moscow  17.100       143.5
# 3         CH   China   Beijing   9.597      1357.0

# %%
import pandas as pd

# %%
print(brics[['country']])
# Out:
#         country
# 0        Brazil
# 1        Russia
# 2         India
# 3         China
# 4  South Africa

# %% [markdown]
# ### lOOPS

# %% [markdown]
# - While loop = repated if statement
# - while condition :
#     expression

# %%
x = 1
while x < 4 :
    print(x)
    x = x + 1
# Out:
# 1
# 2
# 3

# %%
error = 50.0
while error > 1 :
    error = error / 4
    print(error)
# Out:
# 12.5
# 3.125
# 0.78125

# %%
# Initialize offset
offset = 8

# Code the while loop
while offset != 0:
    print('correcting...')
    offset = offset - 1
    print(offset)
# Out:
# correcting...
# 7
# correcting...
# 6
# correcting...
# 5
# correcting...
# 4
# correcting...
# 3
# correcting...
# 2
# correcting...
# 1
# correcting...
# 0

# %% [markdown]
# - For each var in seq , execute expression

# %%
age = [21,22,23,24,25]

for ag in age:
    print(ag)
# Out:
# 21
# 22
# 23
# 24
# 25

# %%
areas = [11.25, 18.0, 20.0, 10.75, 9.50]

# Change for loop to use enumerate() and update print()
for x,y in enumerate(areas) :
    print("room" + str(x) + ':'+ str(y))
# Out:
# room0:11.25
# room1:18.0
# room2:20.0
# room3:10.75
# room4:9.5

# %%
# house list of lists
house = [["hallway", 11.25], 
         ["kitchen", 18.0], 
         ["living room", 20.0], 
         ["bedroom", 10.75], 
         ["bathroom", 9.50]]
         
# Build a for loop from scratch
for sublist in house:
    # Access the room name and area directly from sublist
    room_name = sublist[0]
    room_area = sublist[1]
    print("the " + room_name + " is " + str(room_area) + " sqm")
# Out:
# the hallway is 11.25 sqm
# the kitchen is 18.0 sqm
# the living room is 20.0 sqm
# the bedroom is 10.75 sqm
# the bathroom is 9.5 sqm

# %%
brics
# Out:
#   country_ab       country    capital    area  population
# 0         BR        Brazil   Brasilia   8.516      200.40
# 1         RU        Russia     Moscow  17.100      143.50
# 2         IN         India  New Delhi   3.286     1252.00
# 3         CH         China    Beijing   9.597     1357.00
# 4         SA  South Africa   Pretoria   1.221       52.98

# %%
for lab, row in brics.iterrows():
    print(lab)
    print(row)
# Out:
# 0
# country_ab          BR
# country         Brazil
# capital       Brasilia
# area             8.516
# population       200.4
# Name: 0, dtype: object
# 1
# country_ab        RU
# country       Russia
# capital       Moscow
# area            17.1
# population     143.5
# Name: 1, dtype: object
# 2
# country_ab           IN
# country           India
# capital       New Delhi
# area              3.286
# population       1252.0
# Name: 2, dtype: object
# 3
# country_ab         CH
# country         China
# capital       Beijing
# area            9.597
# population     1357.0
# Name: 3, dtype: object
# 4
# country_ab              SA
# country       South Africa
# capital           Pretoria
# area                 1.221
# population           52.98
# Name: 4, dtype: object

# %%
import numpy as np

np.random.rand()
# Out:
# 0.16526010610009256

# %% [markdown]
# - seed(): sets the random seed, so that your results are reproducible between simulations. As an argument, it takes an integer of your choosing. If you call the function, no output will be generated.
# - rand(): if you don't specify any arguments, it generates a random float between zero and one.

# %%
import numpy as np
np.random.seed(123)

# Use randint() to simulate a dice
print(np.random.randint(1,7))

# Use randint() again
print(np.random.randint(1,7))
# Out:
# 6
# 3
